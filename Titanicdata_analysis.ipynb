# %%
# !pip install pandas
import pandas as pd
# !pip install numpy
import numpy as np
# !pip install matplotlib
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
titanic_data = pd.read_csv("train.csv",delimiter=',')
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
 # To analyse the data we take first five rows of data
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
 # using shape to find how  many rows and columns have in our DataFrame 
titanic_data.shape
# Out:
# (891, 12)

# %%
 # It tells the complete information about our data
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
 # describe method tells that complete overview of our data
print(titanic_data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# detecting null values in our data
print(titanic_data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_data['Age'] = titanic_data['Age'].fillna(titanic_data['Age'].median())
titanic_data['Embarked'] = titanic_data['Embarked'].fillna(titanic_data['Embarked'].mode()[0])
titanic_data['Cabin'] = titanic_data['Cabin'].fillna('Unknown')
 # clearing nullvalues in our data

# %%
print(titanic_data.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
  # Survied count
survived_counts = titanic_data['Survived'].value_counts()
plt.bar(survived_counts.index, survived_counts.values, color=['skyblue', 'mediumseagreen'])
plt.xticks([0, 1], ['Not Survived', 'Survived'])
plt.title('Survival Count')
plt.xlabel('Survival')
plt.ylabel('Count')
plt.show()

# %%
  # Survied Gender 

gender_survived = titanic_data.groupby('Sex')['Survived'].value_counts().unstack()
gender_survived.plot(kind='bar', stacked=True, color=['skyblue', 'mediumseagreen'])
plt.title('Survival by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(['Not Survived', 'Survived'])
plt.show()

# %%
# Suirvived by Passenger Class
class_survived = titanic_data.groupby('Pclass')['Survived'].value_counts().unstack()
class_survived.plot(kind='bar', stacked=True, color=['skyblue', 'mediumseagreen'])
plt.title('Survival by Passenger Class')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(['Not Survived', 'Survived'])
plt.show()

# %%
  # Survival by Embarkation point
embarked_survived = titanic_data.groupby('Embarked')['Survived'].value_counts().unstack()

embarked_survived.plot(kind='bar', stacked=True, color=['skyblue', 'mediumseagreen'])
plt.title('Survival by Embarkation Point')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(['Not Survived', 'Survived'])
plt.show()

# %%
# Histogram plot
plt.hist(titanic_data['Age'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
 # Survival by Age Group
titanic_data['AgeGroup'] = pd.cut(
    titanic_data['Age'],
    bins=[0, 12, 18, 35, 60, 100],
    labels=['Child', 'Teen', 'YoungAdult', 'Adult', 'Senior']
)
agegroup_survived = titanic_data.groupby('AgeGroup', observed=False)['Survived'].value_counts().unstack()


agegroup_survived.plot(kind='bar', stacked=True, color=['skyblue', 'mediumseagreen'])
plt.title('Survival by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(['Not Survived', 'Survived'])
plt.show()

# %%
   # feature Correlation
corr_matrix = titanic_data.corr(numeric_only=True)
fig, ax = plt.subplots(figsize=(10, 6))

cax = ax.imshow(corr_matrix, cmap='coolwarm', interpolation='nearest')

# Add colorbar
fig.colorbar(cax)

# Set ticks and labels
ax.set_xticks(np.arange(len(corr_matrix.columns)))
ax.set_yticks(np.arange(len(corr_matrix.columns)))
ax.set_xticklabels(corr_matrix.columns, rotation=45, ha='right')
ax.set_yticklabels(corr_matrix.columns)


for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        value = round(corr_matrix.iloc[i, j], 2)
        ax.text(j, i, str(value), va='center', ha='center', color='black')

plt.title('Feature Correlation')
plt.tight_layout()
plt.show()

# %%
  # To print all columns
print(titanic_data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'AgeGroup'],
#       dtype='object')

# %%
# 1. Convert categorical to numeric
# Fill missing Embarked with mode
titanic_data['Embarked'] = titanic_data['Embarked'].fillna(titanic_data['Embarked'].mode()[0])

# Encode 'Sex' and 'Embarked' using LabelEncoder
le = LabelEncoder()
titanic_data['Sex'] = le.fit_transform(titanic_data['Sex'])  # male=1, female=0
titanic_data['Embarked'] = le.fit_transform(titanic_data['Embarked'])  # S=2, C=0, Q=1

# 2. Handle missing values
titanic_data['Age'] = titanic_data['Age'].fillna(titanic_data['Age'].median())
titanic_data['Fare'] = titanic_data['Fare'].fillna(titanic_data['Fare'].median())
titanic_data['Cabin'] = titanic_data['Cabin'].fillna('Missing')

# 3. Create new features
# FamilySize = SibSp + Parch + 1
titanic_data['FamilySize'] = titanic_data['SibSp'] + titanic_data['Parch'] + 1

# IsAlone = 1 if FamilySize == 1, else 0
titanic_data['IsAlone'] = (titanic_data['FamilySize'] == 1).astype(int)

# Extract Title from Name
titanic_data['Title'] = titanic_data['Name'].str.extract(' ([A-Za-z]+)\\.', expand=False)

# Simplify titles
titanic_data['Title'] = titanic_data['Title'].replace(
    ['Lady', 'Countess', 'Capt', 'Col', 'Don', 'Dr', 'Major', 
     'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
titanic_data['Title'] = titanic_data['Title'].replace({'Mlle': 'Miss', 'Ms': 'Miss', 'Mme': 'Mrs'})

# Encode Title
titanic_data['Title'] = le.fit_transform(titanic_data['Title'])

# 4. Scale numerical features, but **don't scale 'FamilySize'**
scaler = StandardScaler()
numeric_features = ['Fare']  # Only scale 'Fare'

# Apply scaling
titanic_data[numeric_features] = scaler.fit_transform(titanic_data[numeric_features])

# 5. Remove Negative Values: Shift scaled columns to non-negative values
for feature in numeric_features:
    min_value = titanic_data[feature].min()
    if min_value < 0:
        titanic_data[feature] = titanic_data[feature] - min_value  # Shift values to be non-negative

# (Optional) Drop irrelevant columns for modeling
titanic_data.drop(['PassengerId', 'Name', 'Ticket', 'Cabin','AgeGroup'], axis=1, inplace=True)

# Preview the processed data
print(titanic_data.head())
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked  FamilySize  \
# 0         0       3    1  22.0      1      0  0.145976         2           2
# 1         1       1    0  38.0      1      0  1.435267         0           2
# 2         1       3    0  26.0      0      0  0.159567         2           1
# 3         1       1    0  35.0      1      0  1.069152         2           2
# 4         0       3    1  35.0      0      0  0.162084         2           1
#
#    IsAlone  Title
# 0        0      2
# 1        0      3
# 2        1      1
# 3        0      3
# 4        1      2

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Features and target
X = titanic_data.drop('Survived', axis=1)
y = titanic_data['Survived']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)

print("Logistic Regression:")
print("Accuracy:", accuracy_score(y_test, lr_preds))
print("Confusion Matrix:\n", confusion_matrix(y_test, lr_preds))
print("Classification Report:\n", classification_report(y_test, lr_preds))
# Out:
# Logistic Regression:
# Accuracy: 0.7932960893854749
# Confusion Matrix:
#  [[93 13]
#  [24 49]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       106
#            1       0.79      0.67      0.73        73
#
#     accuracy                           0.79       179
#    macro avg       0.79      0.77      0.78       179
# weighted avg       0.79      0.79      0.79       179

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
rf_preds = rf.predict(X_test)

print("Random Forest:")
print("Accuracy:", accuracy_score(y_test, rf_preds))
print("Confusion Matrix:\n", confusion_matrix(y_test, rf_preds))
print("Classification Report:\n", classification_report(y_test, rf_preds))
# Out:
# Random Forest:
# Accuracy: 0.776536312849162
# Confusion Matrix:
#  [[92 14]
#  [26 47]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82       106
#            1       0.77      0.64      0.70        73
#
#     accuracy                           0.78       179
#    macro avg       0.78      0.76      0.76       179
# weighted avg       0.78      0.78      0.77       179
